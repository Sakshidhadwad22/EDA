# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as w
w.filterwarnings("ignore")

# %%
df=pd.read_csv("cars.csv")
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# ...

# %% [markdown]
# # Handling missing values

# %%
df["normalized-losses"].unique()
# Out:
# array(['?', '164', '158', '192', '188', '121', '98', '81', '118', '148',
#        '110', '145', '137', '101', '78', '106', '85', '107', '104', '113',
#        '150', '129', '115', '93', '142', '161', '153', '125', '128',
#        '122', '103', '168', '108', '194', '231', '119', '154', '74',
#        '186', '83', '102', '89', '87', '77', '91', '134', '65', '197',
#        '90', '94', '256', '95'], dtype=object)

# %%
df["horsepower"].unique()
# Out:
# array(['111', '154', '102', '115', '110', '140', '160', '101', '121',
#        '182', '48', '70', '68', '88', '145', '58', '76', '60', '86',
#        '100', '78', '90', '176', '262', '135', '84', '64', '120', '72',
#        '123', '155', '184', '175', '116', '69', '55', '97', '152', '200',
#        '95', '142', '143', '207', '288', '?', '73', '82', '94', '62',
#        '56', '112', '92', '161', '156', '52', '85', '114', '162', '134',
#        '106'], dtype=object)

# %%
df["normalized-losses"].replace("?",np.nan,inplace=True)
df["horsepower"].replace("?",np.nan,inplace=True)

# %%
df["normalized-losses"]=df["normalized-losses"].astype(float)
df["horsepower"]=df["horsepower"].astype(float)

# %%
df["normalized-losses"].fillna(df["normalized-losses"].mean(),inplace=True)
df["horsepower"].fillna(df["horsepower"].mean(),inplace=True)

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3              122.0  alfa-romero       gas  convertible
# 1            3              122.0  alfa-romero       gas  convertible
# 2            1              122.0  alfa-romero       gas    hatchback
# 3            2              164.0         audi       gas        sedan
# 4            2              164.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1               95.0        volvo       gas        sedan
# 201         -1               95.0        volvo       gas        sedan
# 202         -1               95.0        volvo       gas        sedan
# 203         -1               95.0        volvo    diesel        sedan
# 204         -1               95.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %% [markdown]
# # Outliers removal

# %%
plt.figure(figsize=(8,8))
sns.boxplot(data=df,x="price",y="make")
plt.grid()
plt.show()

# %%
df[(df["make"]=="dodge") & (df["price"]>10000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 29          3              145.0  dodge       gas  hatchback          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 29           front   66.3    50.2         ohc          156       145.0
#
#     city-mpg  highway-mpg  price
# 29        19           24  12964

# %%
df[(df["make"]=="honda") & (df["price"]>12000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 41          0               85.0  honda       gas      sedan          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 41           front   65.2    54.1         ohc          110       101.0
#
#     city-mpg  highway-mpg  price
# 41        24           28  12945

# %%
df[(df["make"]=="isuzu") & (df["price"]>20000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 45          0              122.0  isuzu       gas      sedan          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 45           front   63.6    52.0         ohc           90        70.0
#
#     city-mpg  highway-mpg  price
# 45        38           43  23000

# %%
df[(df["make"]=="mitsubishi") & (df["price"]>13000)]
# Out:
#     symboling  normalized-losses        make fuel-type body-style  \
# 83          3              122.0  mitsubishi       gas  hatchback
# 84          3              122.0  mitsubishi       gas  hatchback
#
#    drive-wheels engine-location  width  height engine-type  engine-size  \
# 83          fwd           front   66.3    50.2         ohc          156
# 84          fwd           front   66.3    50.2         ohc          156
#
#     horsepower  city-mpg  highway-mpg  price
# 83       145.0        19           24  14869
# 84       145.0        19           24  14489

# %%
df[(df["make"]=="plymouth") & (df["price"]>12000)]
# Out:
#      symboling  normalized-losses      make fuel-type body-style drive-wheels  \
# 124          3              122.0  plymouth       gas  hatchback          rwd
#
#     engine-location  width  height engine-type  engine-size  horsepower  \
# 124           front   66.3    50.2         ohc          156       145.0
#
#      city-mpg  highway-mpg  price
# 124        19           24  12764

# %%
df[(df["make"]=="toyota") & (df["price"]>15000)]
# Out:
#      symboling  normalized-losses    make fuel-type   body-style drive-wheels  \
# 172          2              134.0  toyota       gas  convertible          rwd
# 178          3              197.0  toyota       gas    hatchback          rwd
# 179          3              197.0  toyota       gas    hatchback          rwd
# 180         -1               90.0  toyota       gas        sedan          rwd
# 181         -1              122.0  toyota       gas        wagon          rwd
#
#     engine-location  width  height engine-type  engine-size  horsepower  \
# 172           front   65.6    53.0         ohc          146       116.0
# 178           front   67.7    52.0        dohc          171       161.0
# 179           front   67.7    52.0        dohc          171       161.0
# 180           front   66.5    54.1        dohc          171       156.0
# 181           front   66.5    54.1        dohc          161       156.0
#
#      city-mpg  highway-mpg  price
# ...

# %%
df.drop([29,41,45,83,84,124,172,178,179,180,181],axis=0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 194 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          194 non-null    int64
#  1   normalized-losses  194 non-null    float64
#  2   make               194 non-null    object
#  3   fuel-type          194 non-null    object
#  4   body-style         194 non-null    object
#  5   drive-wheels       194 non-null    object
#  6   engine-location    194 non-null    object
#  7   width              194 non-null    float64
#  8   height             194 non-null    float64
#  9   engine-type        194 non-null    object
#  10  engine-size        194 non-null    int64
#  11  horsepower         194 non-null    float64
#  12  city-mpg           194 non-null    int64
#  13  highway-mpg        194 non-null    int64
#  14  price              194 non-null    int64
# dtypes: float64(4), int64(5), object(6)
# ...

# %% [markdown]
# # skewness removal

# %%
colname=df.select_dtypes(["int","float"]).columns
colname
# Out:
# Index(['symboling', 'normalized-losses', 'width', 'height', 'engine-size',
#        'horsepower', 'city-mpg', 'highway-mpg', 'price'],
#       dtype='object')

# %%
from scipy.stats import skew

# %%
for col in df[colname]:
    print(col)
    print(skew(df[col]))
    
    plt.figure()
    sns.distplot(df[col])
    plt.show()
# Out:
# symboling
# 0.21386866184357742
# normalized-losses
# 0.848205953606264
# width
# 0.9140400320504322
# height
# 0.013839962443639326
# engine-size
# 2.0541257626466156
# horsepower
# 1.5556576549504106
# city-mpg
# 0.5999073033714895
# highway-mpg
# 0.4760310091695327
# price
# 1.8166794702973463

# %%
df.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_173ac_row0_col0, #T_173ac_row1_col1, #T_173ac_row2_col2, #T_173ac_row3_col3, #T_173ac_row4_col4, #T_173ac_row5_col5, #T_173ac_row6_col6, #T_173ac_row7_col7, #T_173ac_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_173ac_row0_col1 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_173ac_row0_col2, #T_173ac_row4_col0 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_173ac_row0_col3, #T_173ac_row3_col0, #T_173ac_row3_col1, #T_173ac_row5_col6, #T_173ac_row5_col7, #T_173ac_row6_col5, #T_173ac_row7_col2, #T_173ac_row7_col4, #T_173ac_row7_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_173ac_row0_col4 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_173ac_row0_col5, #T_173ac_row3_col4 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_173ac_row0_col6 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_173ac_row0_col7 {
#   background-color: #7dacd1;
# ...

# %% [markdown]
# ## to remove skewness we need two things 1st in skew value which is close to 0 and 2d thing is correlation which is close to 1 and when both condition is not satisfied that time we remove skewness

# %% [markdown]
# ## there are 2 ways to remove skewness by taking 1) log  OR 2) square root

# %%
df["normalized-losses"]=np.sqrt(df["normalized-losses"])

# %%
skew(df["normalized-losses"])
# Out:
# 0.4136415061835428

# %% [markdown]
# # Handling categorical data (Encoding)

# %%
catcol=df.select_dtypes(object).columns
catcol
# Out:
# Index(['make', 'fuel-type', 'body-style', 'drive-wheels', 'engine-location',
#        'engine-type'],
#       dtype='object')

# %% [markdown]
# ### there are 3 main types of encoder are there 1) One hot encoder 2) Label encoder 3) Ordinal encoder

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
df[catcol]=oe.fit_transform(df[catcol])

# %%
df
# Out:
#      symboling  normalized-losses  make  fuel-type  body-style  drive-wheels  \
# 0            3          11.045361   0.0        1.0         0.0           2.0
# 1            3          11.045361   0.0        1.0         0.0           2.0
# 2            1          11.045361   0.0        1.0         2.0           2.0
# 3            2          12.806248   1.0        1.0         3.0           1.0
# 4            2          12.806248   1.0        1.0         3.0           0.0
# ..         ...                ...   ...        ...         ...           ...
# 200         -1           9.746794  21.0        1.0         3.0           2.0
# 201         -1           9.746794  21.0        1.0         3.0           2.0
# 202         -1           9.746794  21.0        1.0         3.0           2.0
# 203         -1           9.746794  21.0        0.0         3.0           2.0
# 204         -1           9.746794  21.0        1.0         3.0           2.0
#
# ...

# %% [markdown]
# # scalling

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
df.iloc[:,:-1]=ss.fit_transform(df.iloc[:,:-1])
df
# Out:
#      symboling  normalized-losses      make  fuel-type  body-style  \
# 0     1.846173           0.082835 -1.934007   0.339032   -3.111634
# 1     1.846173           0.082835 -1.934007   0.339032   -3.111634
# 2     0.176441           0.082835 -1.934007   0.339032   -0.748984
# 3     1.011307           1.349433 -1.774620   0.339032    0.432341
# 4     1.011307           1.349433 -1.774620   0.339032    0.432341
# ..         ...                ...       ...        ...         ...
# 200  -1.493292          -0.851218  1.413123   0.339032    0.432341
# 201  -1.493292          -0.851218  1.413123   0.339032    0.432341
# 202  -1.493292          -0.851218  1.413123   0.339032    0.432341
# 203  -1.493292          -0.851218  1.413123  -2.949576    0.432341
# 204  -1.493292          -0.851218  1.413123   0.339032    0.432341
#
#      drive-wheels  engine-location     width    height  engine-type  \
# 0        1.234608        -0.125327 -0.820757 -2.056808    -3.110852
# ...
